# %% [markdown]
# ###### Solved questions related to Preprocessing

# %% [markdown]
# ###### Data- Demand_txn

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
1. ###### •	Read the dataset, print last 3 observations and find the data types of each column

# %%
dataset=pd.read_csv("C:\\Users\\Rebecca\\Documents\\TL Study Docs\\ML\\Dataset\\Demand_txn.csv",index_col=0)

# %%
dataset.tail(3)
# Out:
#            City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 9747  Hyderabad         Take Away              4068       2018-01-07
# 9748  Hyderabad          Delivery              4056       2018-01-07
# 9749  Hyderabad          Delivery              4068       2018-01-07
#
#       Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# 9747            274        502.07                 0.05       494.529018
# 9748            370        292.05                 0.05       273.741815
# 9749            186        566.43                 0.05       562.109067
#
#       Percent_Quantity_With_Discount  \
# 9747                             NaN
# 9748                        0.011583
# 9749                             NaN
#
#       Avg_Discount_Percent_On_Discounted_Items        ...          Day  \
# 9747                                       NaN        ...          Sun
# 9748                                  0.104999        ...          Sun
# 9749                                       NaN        ...          Sun
#
#       Car_sales F_and_B_Inflation  F_and_B_Inflation_Adjusted_Effective_Price  \
# 9747    6660.16             140.6                                    3.204332
# 9748    6660.16             140.6                                    1.634010
# 9749    6660.16             140.6                                    3.684986
#
#       F_and_B_Inflation_Adjusted_Median_Price  First_Week_Of_The_Month_Dummy  \
# 9747                                 3.051707                              1
# 9748                                 1.557966                              1
# 9749                                 3.509459                              1
#
#       Last_Week_Of_The_Month_Dummy  Day_Of_The_Week_Seasonality  \
# 9747                             0                         1.75
# 9748                             0                         1.51
# 9749                             0                         1.57
#
#       Month_Of_The_Year_Seasonality  Two_Wheeler_sales
# 9747                           1.06           30726.72
# 9748                           1.17           30726.72
# 9749                           1.17           30726.72
#
# [3 rows x 22 columns]

# %%
dataset.dtypes
# Out:
# City                                           object
# Mapped_Sales_Type                              object
# Mapped_Item_Code                                int64
# Transaction_Date                               object
# Quantity_Sold                                   int64
# Median_Price                                  float64
# Average_Tax_Percent                           float64
# Effective_Price                               float64
# Percent_Quantity_With_Discount                float64
# Avg_Discount_Percent_On_Discounted_Items      float64
# Year                                            int64
# Month                                           int64
# Day                                            object
# Car_sales                                     float64
# F_and_B_Inflation                             float64
# F_and_B_Inflation_Adjusted_Effective_Price    float64
# F_and_B_Inflation_Adjusted_Median_Price       float64
# First_Week_Of_The_Month_Dummy                   int64
# Last_Week_Of_The_Month_Dummy                    int64
# Day_Of_The_Week_Seasonality                   float64
# Month_Of_The_Year_Seasonality                 float64
# Two_Wheeler_sales                             float64
# dtype: object

# %%
2. •	Convert the data type of ‘Mapped_Item_Code’ field to object
o	Hint: use .astype(str) for the data type conversion

# %%
dataset['Mapped_Item_Code'].unique()
# Out:
# array([ 9978,  4064,   965,  1045,  4056,  4065,  4058,  4057,  4061,
#         4055,   979,  4066,   978,  4062,   971,   970,   966,  4068,
#         4063,   964,  4060, 10000,  4059], dtype=int64)

# %%
dataset['Mapped_Item_Code']=dataset['Mapped_Item_Code'].astype(str)

# %%
dataset['Mapped_Item_Code'].dtypes
# Out:
# dtype('O')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9750 entries, 0 to 9749
# Data columns (total 22 columns):
# City                                          9750 non-null object
# Mapped_Sales_Type                             9750 non-null object
# Mapped_Item_Code                              9750 non-null object
# Transaction_Date                              9750 non-null datetime64[ns]
# Quantity_Sold                                 9750 non-null int64
# Median_Price                                  9750 non-null float64
# Average_Tax_Percent                           9750 non-null float64
# Effective_Price                               9749 non-null float64
# Percent_Quantity_With_Discount                4114 non-null float64
# Avg_Discount_Percent_On_Discounted_Items      4112 non-null float64
# Year                                          9750 non-null int64
# Month                                         9750 non-null int64
# Day                                           9750 non-null object
# Car_sales                                     9750 non-null float64
# F_and_B_Inflation                             9750 non-null float64
# F_and_B_Inflation_Adjusted_Effective_Price    9749 non-null float64
# F_and_B_Inflation_Adjusted_Median_Price       9750 non-null float64
# First_Week_Of_The_Month_Dummy                 9750 non-null int64
# Last_Week_Of_The_Month_Dummy                  9750 non-null int64
# Day_Of_The_Week_Seasonality                   9750 non-null float64
# Month_Of_The_Year_Seasonality                 9673 non-null float64
# Two_Wheeler_sales                             9750 non-null float64
# dtypes: datetime64[ns](1), float64(12), int64(5), object(4)
# memory usage: 1.7+ MB

# %%
3. •	Convert the field ‘Transaction_Date’ to datetime (Date) column
o	Hint: use pd.to_datetime for conversion

# %%
dataset['Transaction_Date']=pd.to_datetime(dataset['Transaction_Date'])

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9750 entries, 0 to 9749
# Data columns (total 22 columns):
# City                                          9750 non-null object
# Mapped_Sales_Type                             9750 non-null object
# Mapped_Item_Code                              9750 non-null object
# Transaction_Date                              9750 non-null datetime64[ns]
# Quantity_Sold                                 9750 non-null int64
# Median_Price                                  9750 non-null float64
# Average_Tax_Percent                           9750 non-null float64
# Effective_Price                               9749 non-null float64
# Percent_Quantity_With_Discount                4114 non-null float64
# Avg_Discount_Percent_On_Discounted_Items      4112 non-null float64
# Year                                          9750 non-null int64
# Month                                         9750 non-null int64
# Day                                           9750 non-null object
# Car_sales                                     9750 non-null float64
# F_and_B_Inflation                             9750 non-null float64
# F_and_B_Inflation_Adjusted_Effective_Price    9749 non-null float64
# F_and_B_Inflation_Adjusted_Median_Price       9750 non-null float64
# First_Week_Of_The_Month_Dummy                 9750 non-null int64
# Last_Week_Of_The_Month_Dummy                  9750 non-null int64
# Day_Of_The_Week_Seasonality                   9750 non-null float64
# Month_Of_The_Year_Seasonality                 9673 non-null float64
# Two_Wheeler_sales                             9750 non-null float64
# dtypes: datetime64[ns](1), float64(12), int64(5), object(4)
# memory usage: 1.7+ MB

# %%
4. •	Extract only those records whose transaction date is greater than or equal to ‘2017-01-01’ and proceed with below operations
o	Hint: use .loc operator

# %%
datasetFiltered=dataset[dataset['Transaction_Date']>='2017-01-01']

# %%
datasetFiltered.count()
# Out:
# City                                          9750
# Mapped_Sales_Type                             9750
# Mapped_Item_Code                              9750
# Transaction_Date                              9750
# Quantity_Sold                                 9750
# Median_Price                                  9750
# Average_Tax_Percent                           9750
# Effective_Price                               9749
# Percent_Quantity_With_Discount                4114
# Avg_Discount_Percent_On_Discounted_Items      4112
# Year                                          9750
# Month                                         9750
# Day                                           9750
# Car_sales                                     9750
# F_and_B_Inflation                             9750
# F_and_B_Inflation_Adjusted_Effective_Price    9749
# F_and_B_Inflation_Adjusted_Median_Price       9750
# First_Week_Of_The_Month_Dummy                 9750
# Last_Week_Of_The_Month_Dummy                  9750
# Day_Of_The_Week_Seasonality                   9750
# Month_Of_The_Year_Seasonality                 9673
# Two_Wheeler_sales                             9750
# dtype: int64

# %%
dataset=dataset.loc[dataset['Transaction_Date']>='2017-01-01']

# %%
5•	Check the changed data types of each column and also see how many unique sales types are available in 
‘Mapped_Sales_Type’ column

# %%
dataset.dtypes
# Out:
# City                                                  object
# Mapped_Sales_Type                                     object
# Mapped_Item_Code                                      object
# Transaction_Date                              datetime64[ns]
# Quantity_Sold                                          int64
# Median_Price                                         float64
# Average_Tax_Percent                                  float64
# Effective_Price                                      float64
# Percent_Quantity_With_Discount                       float64
# Avg_Discount_Percent_On_Discounted_Items             float64
# Year                                                   int64
# Month                                                  int64
# Day                                                   object
# Car_sales                                            float64
# F_and_B_Inflation                                    float64
# F_and_B_Inflation_Adjusted_Effective_Price           float64
# F_and_B_Inflation_Adjusted_Median_Price              float64
# First_Week_Of_The_Month_Dummy                          int64
# Last_Week_Of_The_Month_Dummy                           int64
# Day_Of_The_Week_Seasonality                          float64
# Month_Of_The_Year_Seasonality                        float64
# Two_Wheeler_sales                                    float64
# dtype: object

# %%
dataset['Mapped_Sales_Type'].unique()
# Out:
# array(['Take Away', 'Main Hall', 'Express', 'Delivery', 'Dine-in',
#        'Bakery'], dtype=object)

# %%
6. •	Extract only those records whose ‘Avg_Discount_Percent_On_Discounted_Items’ is lesser than 1.0 and do a sense check if the resulting data frame 
contains any values in the same column that are greater than or equal to 1.0

# %%
dataset=dataset.loc[dataset['Avg_Discount_Percent_On_Discounted_Items']<1.0]

# %%
dataset['Avg_Discount_Percent_On_Discounted_Items'].unique()
# Out:
# array([0.10502008, 0.10500575, 0.10500784, ..., 0.57748845, 0.73499869,
#        0.75923651])

# %% [markdown]
# ###### 7. •	Create the below dictionary (dict_agg) and pass it as an argument for the aggregate function in
# order to roll up the results grouped by following order: 'City', 'Mapped_Sales_Type', 'Mapped_Item_Code', 'Transaction_Date'
# o	dict_aggr = {'Quantity_Sold':'sum', 'Median_Price':'median', 'Effective_Price':'median'}
# o	sample syntax: df.groupby(<groupby list>).agg(dictionary)

# %%
dict_aggr={'Quantity_Sold':'sum', 'Median_Price':'median', 'Effective_Price':'median'}

# %%
dict_aggr
# Out:
# {'Quantity_Sold': 'sum', 'Median_Price': 'median', 'Effective_Price': 'median'}

# %%
datasetGroup=dataset.groupby(['City','Mapped_Sales_Type','Mapped_Item_Code','Transaction_Date']).agg(dict_aggr)
datasetGroup
# Out:
#                                                                Quantity_Sold  \
#                                              2018-05-02               542.0
#                                              2018-05-03               542.0
#                                              2018-05-04               542.0
#                                              2018-05-05               542.0
#                                              2018-05-06               542.0
#                                              2018-05-09               542.0
#                                              2018-05-12               542.0
#                                              2018-05-28               542.0
#                                              2018-06-21               542.0
#                                              2018-07-13               542.0
#                             970              2018-04-24               312.0
#                             9978             2018-04-20               187.0
#                                              2018-04-21               187.0
#                                              2018-04-22               187.0
#                                              2018-04-24               187.0
#                                              2018-04-25               187.0
#                                              2018-04-26               187.0
#                                              2018-04-27               187.0
#                                              2018-04-28               187.0
#                                              2018-04-29               187.0
#                                              2018-04-30               187.0
#                                              2018-05-01               187.0
#                                              2018-05-02               187.0
#                                              2018-05-03               187.0
#                                              2018-05-04               187.0
#                                              2018-05-06               187.0
#
#                                                                Effective_Price
# City      Mapped_Sales_Type Mapped_Item_Code Transaction_Date
# Hyderabad Bakery            4059             2018-06-14             314.270000
#                             4060             2018-06-14             332.220000
#                             4063             2018-06-14             666.760000
#           Delivery          4055             2018-01-10             262.359057
#                                              2018-01-11             262.446314
#                                              2018-01-12             262.391672
#                                              2018-01-14             262.357417
#                                              2018-01-15             262.466894
#                                              2018-01-16             262.465386
#                                              2018-01-17             262.458213
#                                              2018-01-19             262.440229
#                                              2018-01-20             262.407380
#                                              2018-01-21             262.418782
#                                              2018-01-22             262.450782
#                                              2018-01-25             262.424083
#                                              2018-01-26             262.478795
#                                              2018-01-27             262.433608
#                                              2018-01-28             262.456297
#                                              2018-01-31             262.349107
#                                              2018-02-01             262.458713
#                                              2018-02-02             262.359001
#                                              2018-02-03             262.371349
#                                              2018-02-04             262.458024
#                                              2018-02-07             262.465101
#                                              2018-02-08             262.428579
#                                              2018-02-09             262.291882
#                                              2018-02-10             262.447509
#                                              2018-02-11             262.392575
#                                              2018-02-12             262.373602
#                                              2018-02-15             257.901706
# ...                                                                        ...
#           Take Away         4068             2018-04-28             487.201803
#                                              2018-04-29             487.201848
#                                              2018-04-30             487.201348
#                                              2018-05-01             487.201266
#                                              2018-05-02             487.202121
#                                              2018-05-03             487.202121
#                                              2018-05-04             487.202037
#                                              2018-05-05             487.202742
#                                              2018-05-06             487.201266
#                                              2018-05-09             535.109589
#                                              2018-05-12             534.405833
#                                              2018-05-28             535.031015
#                                              2018-06-21             523.325333
#                                              2018-07-13             533.900260
#                             970              2018-04-24             269.860000
#                             9978             2018-04-20             162.165385
#                                              2018-04-21             167.893220
#                                              2018-04-22             162.503250
#                                              2018-04-24             161.878696
#                                              2018-04-25             163.940482
#                                              2018-04-26             168.476901
#                                              2018-04-27             167.010227
#                                              2018-04-28             167.634722
#                                              2018-04-29             167.599546
#                                              2018-04-30             164.592632
#                                              2018-05-01             161.523636
#                                              2018-05-02             169.316049
#                                              2018-05-03             164.509565
#                                              2018-05-04             164.507619
#                                              2018-05-06             163.006087
#
# [3367 rows x 3 columns]

# %%
8. •	Print first 5 observations where Effective_Price is not null

# %%
dataset[dataset['Effective_Price'].isnull()].head(5)
# Out:
# Empty DataFrame
# Columns: [City, Mapped_Sales_Type, Mapped_Item_Code, Transaction_Date, Quantity_Sold, Median_Price, Average_Tax_Percent, Effective_Price, Percent_Quantity_With_Discount, Avg_Discount_Percent_On_Discounted_Items, Year, Month, Day, Car_sales, F_and_B_Inflation, F_and_B_Inflation_Adjusted_Effective_Price, F_and_B_Inflation_Adjusted_Median_Price, First_Week_Of_The_Month_Dummy, Last_Week_Of_The_Month_Dummy, Day_Of_The_Week_Seasonality, Month_Of_The_Year_Seasonality, Two_Wheeler_sales]
# Index: []
#
# [0 rows x 22 columns]

# %%
dataset[dataset['Effective_Price'].notnull()].head(5)
# Out:
#          City Mapped_Sales_Type Mapped_Item_Code Transaction_Date  \
# 5   Hyderabad          Delivery             4056       2018-07-31
# 10  Hyderabad          Delivery             4061       2018-07-31
# 20  Hyderabad           Dine-in              966       2018-07-31
# 24  Hyderabad           Dine-in              965       2018-07-31
# 26  Hyderabad          Delivery             4068       2018-07-31
#
#     Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# 5             617         322.0                 0.05       305.354585
# 10            144         942.0                 0.05       942.631515
# 20           1250         392.0                 0.05       378.840053
# 24           1934         362.0                 0.05       347.258327
# 26            148         622.0                 0.05       618.898649
#
#     Percent_Quantity_With_Discount  Avg_Discount_Percent_On_Discounted_Items  \
# 5                         0.003953                                  0.105020
# 10                        0.151515                                  0.105006
# 20                        0.003512                                  0.105008
# 24                        0.001646                                  0.420000
# 26                        0.027027                                  0.105009
#
#           ...          Day  Car_sales F_and_B_Inflation  \
# 5         ...          Tue    7559.28             143.7
# 10        ...          Tue    7559.28             143.7
# 20        ...          Tue    7559.28             143.7
# 24        ...          Tue    7559.28             143.7
# 26        ...          Tue    7559.28             143.7
#
#     F_and_B_Inflation_Adjusted_Effective_Price  \
# 5                                     1.818751
# 10                                    6.253525
# 20                                    2.330133
# 24                                    2.110357
# 26                                    4.000686
#
#     F_and_B_Inflation_Adjusted_Median_Price  First_Week_Of_The_Month_Dummy  \
# 5                                  1.732777                              0
# 10                                 6.047321                              0
# 20                                 2.219903                              0
# 24                                 2.011134                              0
# 26                                 3.820459                              0
#
#     Last_Week_Of_The_Month_Dummy  Day_Of_The_Week_Seasonality  \
# 5                              1                         0.82
# 10                             1                         0.75
# 20                             1                         0.92
# 24                             1                         0.89
# 26                             1                         0.64
#
#     Month_Of_The_Year_Seasonality  Two_Wheeler_sales
# 5                            1.06           37307.52
# 10                           1.06           37307.52
# 20                           1.09           37307.52
# 24                           1.09           37307.52
# 26                           1.06           37307.52
#
# [5 rows x 22 columns]

# %%
9.•	Print first 10 observations where ‘City’ is ‘Hyderabad’ AND ‘Mapped_Sales_Type’ is ‘Delivery’
o	Hint: df.loc[(<condition 1>) & (<condition 2>), :].head(10)

# %%
dataset.loc[dataset['City'].str.contains('Hyderabad') & dataset['Mapped_Sales_Type'].str.contains('Delivery')].head(10)
# Out:
#          City Mapped_Sales_Type Mapped_Item_Code Transaction_Date  \
# 5   Hyderabad          Delivery             4056       2018-07-31
# 10  Hyderabad          Delivery             4061       2018-07-31
# 26  Hyderabad          Delivery             4068       2018-07-31
# 42  Hyderabad          Delivery             4058       2018-07-31
# 46  Hyderabad          Delivery             4064       2018-07-31
# 62  Hyderabad          Delivery             4068       2018-07-30
# 75  Hyderabad          Delivery             4065       2018-07-30
# 77  Hyderabad          Delivery             4056       2018-07-30
# 88  Hyderabad          Delivery             4064       2018-07-30
# 89  Hyderabad          Delivery             4058       2018-07-30
#
#     Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# 5             617         322.0                 0.05       305.354585
# 10            144         942.0                 0.05       942.631515
# 26            148         622.0                 0.05       618.898649
# 42            532         272.0                 0.05       252.660214
# 46            261         682.0                 0.05       683.031933
# 62            139         622.0                 0.05       618.399286
# 75            133         752.0                 0.05       750.476818
# 77            485         322.0                 0.05       305.108823
# 88            230         682.0                 0.05       680.233950
# 89            473         272.0                 0.05       252.668923
#
#     Percent_Quantity_With_Discount  Avg_Discount_Percent_On_Discounted_Items  \
# 5                         0.003953                                  0.105020
# 10                        0.151515                                  0.105006
# 26                        0.027027                                  0.105009
# 42                        0.014252                                  0.105008
# 46                        0.006667                                  0.105008
# 62                        0.035714                                  0.105009
# 75                        0.090909                                  0.105007
# 77                        0.013369                                  0.105004
# 88                        0.050420                                  0.105005
# 89                        0.013812                                  0.105005
#
#           ...          Day  Car_sales F_and_B_Inflation  \
# 5         ...          Tue    7559.28             143.7
# 10        ...          Tue    7559.28             143.7
# 26        ...          Tue    7559.28             143.7
# 42        ...          Tue    7559.28             143.7
# 46        ...          Tue    7559.28             143.7
# 62        ...          Mon    7559.28             143.7
# 75        ...          Mon    7559.28             143.7
# 77        ...          Mon    7559.28             143.7
# 88        ...          Mon    7559.28             143.7
# 89        ...          Mon    7559.28             143.7
#
#     F_and_B_Inflation_Adjusted_Effective_Price  \
# 5                                     1.818751
# 10                                    6.253525
# 26                                    4.000686
# 42                                    1.452054
# 46                                    4.446986
# 62                                    3.997211
# 75                                    4.916331
# 77                                    1.817041
# 88                                    4.427515
# 89                                    1.452115
#
#     F_and_B_Inflation_Adjusted_Median_Price  First_Week_Of_The_Month_Dummy  \
# 5                                  1.732777                              0
# 10                                 6.047321                              0
# 26                                 3.820459                              0
# 42                                 1.384830                              0
# 46                                 4.237996                              0
# 62                                 3.820459                              0
# 75                                 4.725122                              0
# 77                                 1.732777                              0
# 88                                 4.237996                              0
# 89                                 1.384830                              0
#
#     Last_Week_Of_The_Month_Dummy  Day_Of_The_Week_Seasonality  \
# 5                              1                         0.82
# 10                             1                         0.75
# 26                             1                         0.64
# 42                             1                         0.72
# 46                             1                         0.76
# 62                             1                         0.65
# 75                             1                         0.60
# 77                             1                         0.72
# 88                             1                         0.61
# 89                             1                         0.71
#
#     Month_Of_The_Year_Seasonality  Two_Wheeler_sales
# 5                            1.06           37307.52
# 10                           1.06           37307.52
# 26                           1.06           37307.52
# 42                           1.06           37307.52
# 46                           1.06           37307.52
# 62                           1.06           37307.52
# 75                           1.06           37307.52
# 77                           1.06           37307.52
# 88                           1.06           37307.52
# 89                           1.06           37307.52
#
# [10 rows x 22 columns]

# %%
10. •	Print first 3 observations where Percent_Quantity_With_Discount is not equal to zero
o	Hint: use != operator

# %%
dataset.loc[dataset['Percent_Quantity_With_Discount']!=0].head(3)
# Out:
#          City Mapped_Sales_Type Mapped_Item_Code Transaction_Date  \
# 5   Hyderabad          Delivery             4056       2018-07-31
# 10  Hyderabad          Delivery             4061       2018-07-31
# 20  Hyderabad           Dine-in              966       2018-07-31
#
#     Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# 5             617         322.0                 0.05       305.354585
# 10            144         942.0                 0.05       942.631515
# 20           1250         392.0                 0.05       378.840053
#
#     Percent_Quantity_With_Discount  Avg_Discount_Percent_On_Discounted_Items  \
# 5                         0.003953                                  0.105020
# 10                        0.151515                                  0.105006
# 20                        0.003512                                  0.105008
#
#           ...          Day  Car_sales F_and_B_Inflation  \
# 5         ...          Tue    7559.28             143.7
# 10        ...          Tue    7559.28             143.7
# 20        ...          Tue    7559.28             143.7
#
#     F_and_B_Inflation_Adjusted_Effective_Price  \
# 5                                     1.818751
# 10                                    6.253525
# 20                                    2.330133
#
#     F_and_B_Inflation_Adjusted_Median_Price  First_Week_Of_The_Month_Dummy  \
# 5                                  1.732777                              0
# 10                                 6.047321                              0
# 20                                 2.219903                              0
#
#     Last_Week_Of_The_Month_Dummy  Day_Of_The_Week_Seasonality  \
# 5                              1                         0.82
# 10                             1                         0.75
# 20                             1                         0.92
#
#     Month_Of_The_Year_Seasonality  Two_Wheeler_sales
# 5                            1.06           37307.52
# 10                           1.06           37307.52
# 20                           1.09           37307.52
#
# [3 rows x 22 columns]

# %%
11. •	Create a new column ‘Range’ and populate it as 1 if Effective_Price is greater than 500, else 0.5
o	Hint: df[‘New column’] = np.where(<condition>, if true, if false)

# %%
dataset['Range']=[1 if x >500 else 0.5 for x in dataset['Effective_Price']]

# %%
dataset.head(2)
# Out:
#          City Mapped_Sales_Type Mapped_Item_Code Transaction_Date  \
# 5   Hyderabad          Delivery             4056       2018-07-31
# 10  Hyderabad          Delivery             4061       2018-07-31
#
#     Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# 5             617         322.0                 0.05       305.354585
# 10            144         942.0                 0.05       942.631515
#
#     Percent_Quantity_With_Discount  Avg_Discount_Percent_On_Discounted_Items  \
# 5                         0.003953                                  0.105020
# 10                        0.151515                                  0.105006
#
#     ...    Car_sales  F_and_B_Inflation  \
# 5   ...      7559.28              143.7
# 10  ...      7559.28              143.7
#
#    F_and_B_Inflation_Adjusted_Effective_Price  \
# 5                                    1.818751
# 10                                   6.253525
#
#     F_and_B_Inflation_Adjusted_Median_Price  First_Week_Of_The_Month_Dummy  \
# 5                                  1.732777                              0
# 10                                 6.047321                              0
#
#     Last_Week_Of_The_Month_Dummy  Day_Of_The_Week_Seasonality  \
# 5                              1                         0.82
# 10                             1                         0.75
#
#     Month_Of_The_Year_Seasonality  Two_Wheeler_sales  Range
# 5                            1.06           37307.52    0.5
# 10                           1.06           37307.52    1.0
#
# [2 rows x 23 columns]

# %%
op=['Mapped_Item_Code', 'Median_Price', 'Average_Tax_Percent','Effective_Price', 'Percent_Quantity_With_Discount',
   'Avg_Discount_Percent_On_Discounted_Items','Car_sales', 'F_and_B_Inflation','F_and_B_Inflation_Adjusted_Effective_Price','Quantity_Sold']

XxYy=dataset[op]

# %%
XxYy.corr()
# Out:
#                                             Median_Price  Average_Tax_Percent  \
# Median_Price                                1.000000e+00         7.123332e-15
# Average_Tax_Percent                         7.123332e-15         1.000000e+00
# Effective_Price                             9.983656e-01         4.482249e-16
# Percent_Quantity_With_Discount              2.140664e-01         4.073250e-16
# Avg_Discount_Percent_On_Discounted_Items   -2.282925e-01        -2.877990e-15
# Car_sales                                   1.531538e-02        -3.782378e-13
# F_and_B_Inflation                           2.091315e-02         1.241327e-12
# F_and_B_Inflation_Adjusted_Effective_Price  9.983624e-01         3.508083e-15
# Quantity_Sold                              -4.832408e-01         1.322693e-15
#
#                                             Effective_Price  \
# Median_Price                                   9.983656e-01
# Average_Tax_Percent                            4.482249e-16
# Effective_Price                                1.000000e+00
# Percent_Quantity_With_Discount                 1.613933e-01
# Avg_Discount_Percent_On_Discounted_Items      -2.257972e-01
# Car_sales                                      3.188454e-02
# F_and_B_Inflation                              2.953283e-02
# F_and_B_Inflation_Adjusted_Effective_Price     9.997717e-01
# Quantity_Sold                                 -4.760799e-01
#
#                                             Percent_Quantity_With_Discount  \
# Median_Price                                                  2.140664e-01
# Average_Tax_Percent                                           4.073250e-16
# Effective_Price                                               1.613933e-01
# Percent_Quantity_With_Discount                                1.000000e+00
# Avg_Discount_Percent_On_Discounted_Items                     -1.752703e-01
# Car_sales                                                    -3.145468e-01
# F_and_B_Inflation                                            -1.582320e-01
# F_and_B_Inflation_Adjusted_Effective_Price                    1.650175e-01
# Quantity_Sold                                                -2.531248e-01
#
#                                             Avg_Discount_Percent_On_Discounted_Items  \
# Median_Price                                                           -2.282925e-01
# Average_Tax_Percent                                                    -2.877990e-15
# Effective_Price                                                        -2.257972e-01
# Percent_Quantity_With_Discount                                         -1.752703e-01
# Avg_Discount_Percent_On_Discounted_Items                                1.000000e+00
# Car_sales                                                               1.682464e-02
# F_and_B_Inflation                                                       2.669008e-02
# F_and_B_Inflation_Adjusted_Effective_Price                             -2.262400e-01
# Quantity_Sold                                                           4.312312e-01
#
#                                                Car_sales  F_and_B_Inflation  \
# Median_Price                                1.531538e-02       2.091315e-02
# Average_Tax_Percent                        -3.782378e-13       1.241327e-12
# Effective_Price                             3.188454e-02       2.953283e-02
# Percent_Quantity_With_Discount             -3.145468e-01      -1.582320e-01
# Avg_Discount_Percent_On_Discounted_Items    1.682464e-02       2.669008e-02
# Car_sales                                   1.000000e+00       3.746624e-01
# F_and_B_Inflation                           3.746624e-01       1.000000e+00
# F_and_B_Inflation_Adjusted_Effective_Price  2.492164e-02       1.138390e-02
# Quantity_Sold                               6.654979e-02       9.486292e-02
#
#                                             F_and_B_Inflation_Adjusted_Effective_Price  \
# Median_Price                                                              9.983624e-01
# Average_Tax_Percent                                                       3.508083e-15
# Effective_Price                                                           9.997717e-01
# Percent_Quantity_With_Discount                                            1.650175e-01
# Avg_Discount_Percent_On_Discounted_Items                                 -2.262400e-01
# Car_sales                                                                 2.492164e-02
# F_and_B_Inflation                                                         1.138390e-02
# F_and_B_Inflation_Adjusted_Effective_Price                                1.000000e+00
# Quantity_Sold                                                            -4.777277e-01
#
#                                             Quantity_Sold
# Median_Price                                -4.832408e-01
# Average_Tax_Percent                          1.322693e-15
# Effective_Price                             -4.760799e-01
# Percent_Quantity_With_Discount              -2.531248e-01
# Avg_Discount_Percent_On_Discounted_Items     4.312312e-01
# Car_sales                                    6.654979e-02
# F_and_B_Inflation                            9.486292e-02
# F_and_B_Inflation_Adjusted_Effective_Price  -4.777277e-01
# Quantity_Sold                                1.000000e+00

# %%
12.•	Split the dataset into X and Y based on below list:
x = 'Mapped_Item_Code', 'Median_Price', 'Average_Tax_Percent',  
'Effective_Price', 'Percent_Quantity_With_Discount',
'Avg_Discount_Percent_On_Discounted_Items','Car_sales', 'F_and_B_Inflation',
'F_and_B_Inflation_Adjusted_Effective_Price',
'F_and_B_Inflation_Adjusted_Median_Price'. And  y = ‘Quantity_Sold’

# %%
x=['Mapped_Item_Code', 'Median_Price', 'Average_Tax_Percent','Effective_Price', 'Percent_Quantity_With_Discount',
   'Avg_Discount_Percent_On_Discounted_Items','Car_sales', 'F_and_B_Inflation','F_and_B_Inflation_Adjusted_Effective_Price',
'F_and_B_Inflation_Adjusted_Median_Price']
x1=['Mapped_Item_Code', 'Median_Price', 'Average_Tax_Percent','Effective_Price', 'Percent_Quantity_With_Discount',
   'Avg_Discount_Percent_On_Discounted_Items','Car_sales', 'F_and_B_Inflation','F_and_B_Inflation_Adjusted_Effective_Price']
X=dataset[x]
X1=dataset[x1]

# %%
X.head(2)
# Out:
#    Mapped_Item_Code  Median_Price  Average_Tax_Percent  Effective_Price  \
# 5              4056         322.0                 0.05       305.354585
# 10             4061         942.0                 0.05       942.631515
#
#     Percent_Quantity_With_Discount  Avg_Discount_Percent_On_Discounted_Items  \
# 5                         0.003953                                  0.105020
# 10                        0.151515                                  0.105006
#
#     Car_sales  F_and_B_Inflation  F_and_B_Inflation_Adjusted_Effective_Price  \
# 5     7559.28              143.7                                    1.818751
# 10    7559.28              143.7                                    6.253525
#
#     F_and_B_Inflation_Adjusted_Median_Price
# 5                                  1.732777
# 10                                 6.047321

# %%
y ='Quantity_Sold'
Y=dataset[y]
Y.head(2)
# Out:
# 5     617
# 10    144
# Name: Quantity_Sold, dtype: int64

# %%
Y.dtypes
# Out:
# dtype('int64')

# %%
X.dtypes
# Out:
# Mapped_Item_Code                                int32
# Median_Price                                  float64
# Average_Tax_Percent                           float64
# Effective_Price                               float64
# Percent_Quantity_With_Discount                float64
# Avg_Discount_Percent_On_Discounted_Items      float64
# Car_sales                                     float64
# F_and_B_Inflation                             float64
# F_and_B_Inflation_Adjusted_Effective_Price    float64
# F_and_B_Inflation_Adjusted_Median_Price       float64
# dtype: object

# %% [markdown]
# 13.•	Run the Linear Regression model on the above x and y features.
# Feel free to explore the modeling parameters and come up with a high R2
# •	While fitting x and y to get stats summary, data type of x should be converted to float due to categorical features, otherwise the summary would return error
# o	Hint: sm.OLS(y, x.astype(float)).fit()

# %%
X.dtypes
# Out:
# Mapped_Item_Code                                int32
# Median_Price                                  float64
# Average_Tax_Percent                           float64
# Effective_Price                               float64
# Percent_Quantity_With_Discount                float64
# Avg_Discount_Percent_On_Discounted_Items      float64
# Car_sales                                     float64
# F_and_B_Inflation                             float64
# F_and_B_Inflation_Adjusted_Effective_Price    float64
# F_and_B_Inflation_Adjusted_Median_Price       float64
# dtype: object

# %%
X['Mapped_Item_Code']=X['Mapped_Item_Code'].astype(int)
X1['Mapped_Item_Code']=X1['Mapped_Item_Code'].astype(int)
# Out:
# C:\Users\Rebecca\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Rebecca\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3367 entries, 5 to 9748
# Data columns (total 10 columns):
# Mapped_Item_Code                              3367 non-null int32
# Median_Price                                  3367 non-null float64
# Average_Tax_Percent                           3367 non-null float64
# Effective_Price                               3367 non-null float64
# Percent_Quantity_With_Discount                3367 non-null float64
# Avg_Discount_Percent_On_Discounted_Items      3367 non-null float64
# Car_sales                                     3367 non-null float64
# F_and_B_Inflation                             3367 non-null float64
# F_and_B_Inflation_Adjusted_Effective_Price    3367 non-null float64
# F_and_B_Inflation_Adjusted_Median_Price       3367 non-null float64
# dtypes: float64(9), int32(1)
# memory usage: 276.2 KB

# %%
from sklearn.model_selection import train_test_split

# %%
Xtrain,Xtest,Ytrain,Ytest=train_test_split(X,Y,test_size=0.3,random_state=101)

# %%
X1train,X1test,Y1train,Y1test=train_test_split(X1,Y,test_size=0.3,random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(Xtrain,Ytrain)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
lr.fit(X1train,Y1train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
outPredicted=lr.predict(Xtest)

# %%
outPredicted1=lr.predict(X1test)

# %%
list(zip(Ytest,outPredicted))
# Out:
# [(2634, 698.275584262241),
#  (136, 356.06354348508285),
#  (761, 673.1876044684268),
#  (788, 735.3124137921859),
#  (280, 702.4350659758948),
#  (1208, 1488.3215917577272),
#  (377, 297.21392689314234),
#  (190, 724.4949655590481),
#  (515, 689.8474584447576),
#  (454, 643.6268287828279),
#  (632, 639.6552962266069),
#  (362, 544.1409865138121),
#  (475, 698.970724045912),
#  (150, 253.93950234182012),
#  (915, 679.5091405363764),
#  (218, 555.4609198373582),
#  (393, 588.9181534820091),
#  (457, 643.0662731638604),
#  (273, 688.657508838056),
#  (194, 693.8169197491261),
#  (126, 3.4173305527056073),
#  (161, 88.58714480680464),
#  (235, 241.94647979142974),
#  (176, 478.9519403225204),
#  (538, 360.5966813987088),
#  (2514, 753.5590245802232),
#  (149, 223.824976372538),
#  (403, 552.1845662136566),
#  (1108, 891.7208332628798),
#  (807, 1477.3950566290187),
#  (1277, 1304.616685761388),
#  (321, 1368.8465432362373),
#  (1917, 1481.916157440919),
#  (143, 269.6750817717875),
#  (156, 48.13239736004107),
#  (1041, 673.725394641162),
#  (652, 654.5449826618133),
#  (483, 567.5972621834717),
#  (525, 643.8338362289942),
#  (321, 1404.348986361947),
#  (939, 1133.838608833421),
#  (209, 436.00451006104595),
#  (1484, 1353.4557791716961),
#  (132, 163.82763789078672),
#  (442, 664.2314214564012),
#  (238, 698.9813395552646),
#  (2290, 1074.0407866967398),
#  (1437, 1615.9358428350115),
#  (1431, 788.291016991916),
#  (515, 729.7996164827091),
#  (184, 396.8238808696078),
#  (842, 969.5379245413424),
#  (135, 46.74644711774636),
#  (141, 111.1293528255519),
#  (491, 878.753657507621),
#  (757, 1397.5214938234258),
#  (317, 688.5863634026791),
#  (133, 55.503553370568625),
#  (234, 584.9843105991604),
#  (612, 1767.5087697623421),
#  (693, 561.7207300094342),
#  (373, 675.1181276675907),
#  (229, 217.4570813658229),
#  (401, 630.8957675751863),
#  (388, 597.6073352807962),
#  (345, 826.4992530179152),
#  (1950, 711.4903742215756),
#  (183, 217.6749667562999),
#  (359, 1235.5583310127058),
#  (149, 341.77447160107295),
#  (766, 787.9403281346858),
#  (140, 255.40624318145456),
#  (124, 235.93017411287292),
#  (154, 50.96153011543538),
#  (1322, 666.2354499415032),
#  (166, 5.097898341931796),
#  (280, 297.4356231817874),
#  (148, 226.86345460018856),
#  (199, 815.2000807713321),
#  (392, 1211.8674562246506),
#  (147, -66.96714130547207),
#  (159, 164.04293990609222),
#  (158, 226.4425099124819),
#  (813, 699.0839470783558),
#  (2660, 2002.189099286652),
#  (517, 547.3816268272258),
#  (592, 1281.5550450660921),
#  (1202, 1460.4548395374368),
#  (917, 718.9257073853423),
#  (474, 699.0991260155843),
#  (3276, 1353.012420363817),
#  (1595, 1459.8225597674573),
#  (2694, 1244.98950093058),
#  (1064, 666.1887540288899),
#  (132, 255.1242621136971),
#  (2186, 1259.8106165975332),
#  (133, 35.92673282774376),
#  (236, 438.0811183676942),
#  (183, -332.8430105874113),
#  (822, 730.2460544921232),
#  (469, 308.0559374762979),
#  (300, 72.42806625929916),
#  (1169, 776.1370475143558),
#  (154, 273.0284935891723),
#  (253, 318.5230346465287),
#  (868, 1230.9108242969924),
#  (394, 567.7377598819494),
#  (158, -5.000451536669061),
#  (267, 326.72003916300855),
#  (143, 439.17246265448375),
#  (418, 292.5611856433861),
#  (1789, 842.1621755390806),
#  (229, 385.683564674624),
#  (2125, 1548.4989410641865),
#  (736, 898.1544294937557),
#  (135, 274.5173215579398),
#  ...]

# %%
Ytest.head(2)
# Out:
# 4785    2634
# 7708     136
# Name: Quantity_Sold, dtype: int64

# %%
from sklearn import metrics

# %%
metrics.mean_squared_error(Ytest,outPredicted)
# Out:
# 241760.15951719132

# %%
metrics.mean_squared_error(Y1test,outPredicted1)
# Out:
# 241757.1312108636

# %%
import statsmodels.formula.api as sm

# %%
result=sm.OLS(Y,X).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Quantity_Sold   R-squared:                       0.502
# Model:                            OLS   Adj. R-squared:                  0.500
# Method:                 Least Squares   F-statistic:                     375.3
# Date:                Fri, 03 May 2019   Prob (F-statistic):               0.00
# Time:                        19:59:04   Log-Likelihood:                -25427.
# No. Observations:                3367   AIC:                         5.087e+04
# Df Residuals:                    3357   BIC:                         5.094e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================================================
#                                                  coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------
# Mapped_Item_Code                              -0.1842      0.006    -30.754      0.000      -0.196      -0.172
# Median_Price                                  79.5127    143.634      0.554      0.580    -202.107     361.133
# Average_Tax_Percent                        -1.375e+05   9.49e+04     -1.449      0.147   -3.24e+05    4.86e+04
# Effective_Price                              -81.4379    137.797     -0.591      0.555    -351.613     188.737
# Percent_Quantity_With_Discount                24.9372    100.021      0.249      0.803    -171.172     221.046
# Avg_Discount_Percent_On_Discounted_Items     939.1182     48.379     19.412      0.000     844.263    1033.974
# Car_sales                                      0.0565      0.022      2.591      0.010       0.014       0.099
# F_and_B_Inflation                             41.8434     10.153      4.121      0.000      21.937      61.750
# F_and_B_Inflation_Adjusted_Effective_Price  1.144e+04   1.93e+04      0.594      0.553   -2.63e+04    4.92e+04
# F_and_B_Inflation_Adjusted_Median_Price    -1.133e+04   2.01e+04     -0.564      0.573   -5.07e+04     2.8e+04
# ==============================================================================
# Omnibus:                      875.363   Durbin-Watson:                   1.934
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3229.582
# Skew:                           1.254   Prob(JB):                         0.00
# Kurtosis:                       7.091   Cond. No.                     9.78e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.78e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
result1=sm.OLS(Y,X1).fit()
result1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Quantity_Sold   R-squared:                       0.502
# Model:                            OLS   Adj. R-squared:                  0.500
# Method:                 Least Squares   F-statistic:                     422.3
# Date:                Fri, 03 May 2019   Prob (F-statistic):               0.00
# Time:                        20:15:52   Log-Likelihood:                -25427.
# No. Observations:                3367   AIC:                         5.087e+04
# Df Residuals:                    3358   BIC:                         5.093e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================================================
#                                                  coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------
# Mapped_Item_Code                              -0.1841      0.006    -30.753      0.000      -0.196      -0.172
# Median_Price                                  -1.5505      1.597     -0.971      0.332      -4.682       1.581
# Average_Tax_Percent                        -8.598e+04    2.6e+04     -3.313      0.001   -1.37e+05   -3.51e+04
# Effective_Price                               -3.6810      2.855     -1.289      0.197      -9.279       1.917
# Percent_Quantity_With_Discount                24.8013    100.011      0.248      0.804    -171.287     220.890
# Avg_Discount_Percent_On_Discounted_Items     939.8454     48.357     19.436      0.000     845.033    1034.658
# Car_sales                                      0.0566      0.022      2.597      0.009       0.014       0.099
# F_and_B_Inflation                             41.2638     10.100      4.086      0.000      21.462      61.066
# F_and_B_Inflation_Adjusted_Effective_Price   569.9029    369.226      1.544      0.123    -154.027    1293.833
# ==============================================================================
# Omnibus:                      878.841   Durbin-Watson:                   1.935
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3258.323
# Skew:                           1.257   Prob(JB):                         0.00
# Kurtosis:                       7.111   Cond. No.                     2.57e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.57e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
